# %% [markdown]
# <img src="../logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Evidencias clase 10
# #### Lugano Damian

# %% [markdown]
# ### Tareas de esta semana en orden de prioridad
#
# * Mirar la clase 8
#
# * Terminar de diseñar el circuito del TPLAB1 y probabarlo en el laboratorio abierto
#
# * Hacer el ejercicio 8 de la guia 3 que quedó pendiente de clase

# %% [markdown]
# ### Videos de la clase 8
#
# Se miraron los videos de la clase 8 donde se trataron los temas de cuadripolos. Si bien cuadripolos es un tema que ya habia visto reiteradas veces en la carrera, si es cierto que en esta ocasión los vi un poco más en profundidad y desde otro punto de vista también.
#
# Foto mirando la clase
#
# <img src="./pics/clase10.jpg" align="center" width="1000" />
#
# En esta clase tambíen tuve la oportunidad de usar mucha bibliografía, en este caso utilizé el libro de Araujo:
#
# Bibliografía Araujo Capítulo 5 Página 268, Cuadripolo T
#
# <img src="./pics/araujo1.png" align="center" width="1000" />
#
# Bibliografía Araujo Capítulo 5 Página 270, Cuadripolo T (polo compacto)
#
# <img src="./pics/araujo2.png" align="center" width="1000" />
#
# Bibliografía Araujo Capítulo 5 Página 278, Cuadripolo Lattice
#
# <img src="./pics/araujo3.png" align="center" width="1000" />
#
# Tambien utilizé unos apuntes de Electrónica Aplicada 2 que tenian teoría de cuadripolos
#
# Parámetros Z
#
# <img src="./pics/parametrosz.png" align="center" width="1000" />
#
# Parámetros Y
#
# <img src="./pics/parametrosy.png" align="center" width="1000" />

# %% [markdown]
# ## Apuntes tomados en la clase

# %%
from IPython.display import IFrame
IFrame("./docs/apuntes_clase10.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./docs/apuntes_clase10.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## TPLAB 1 - Diseño y Armado
#
# Finalmente se terminó el diseño del circuito para el TPLAB1. Solo quedaba asignar el valor de los componentes.
#
# Circuito esquemático en SPICE
#
# ![image.png](attachment:image.png)
#
# Simulación donde se puede ver que cumple con la atenuación máxima de 0.5dB en la banda de paso
#
# ![image-2.png](attachment:image-2.png)
#
# A continuación el armado del circuito y su prueba en el laboratorio abierto:
#
# Protoboard del filtro
#
# <img src="./pics/prototp1.jpg" align="center" width="1000" />
#
# Probando el filtro en el laboratorio abierto
#
# <img src="./pics/LabAbierto.jpg" align="center" width="1000" />

# %% [markdown]
# ### Ejercicio 8 de la guia 3
#
# Se resolvieron los ejercicios 8b y 8c de la guia 3 donde se pedia diseñar filtros Notch con la configuración Ack-Moss ya que aún no habia hecho ningún ejercicio de Notch.

# %%
from IPython.display import IFrame
IFrame("./docs/ej8guia3.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./docs/ej8guia3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulaciones circuitales
#
# Notch fo=50Hz
#
# <img src="./pics/Notch50hz.png" align="center" width="1000" />
#
# Notch Lowpass
#
# <img src="./pics/NotchLowPass.png" align="center" width="1000" />
