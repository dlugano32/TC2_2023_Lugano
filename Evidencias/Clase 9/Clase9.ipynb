# %% [markdown]
# <img src="../logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Evidencias clase 9
# #### Lugano Damian

# %% [markdown]
# Esta semana se juntaron varias cosas:
#
# -Ver la clase teórica 7
#
# -Arrancar con el diseño del TPLAB1
#
# -Hacer la tarea semanal 4bis2
#
# Si bien la tarea semanal 4bis2 y el TPLAB1 no eran esta semana, yo siempre trato de hacer las cosas lo antes posible porque me organizo asi. De todas maneras la cantidad de horas dedicadas fueron bastantes : **16hs**

# %% [markdown]
# ## Clase teórica 7
#
# Se vieron los videos de la clase 7, los cuales tratan los temas de funciones bilineales y bicuadráticas. En este punto de la materia no fueron conceptos nuevos, pero se los vé desde otro punto de vista. Lo más interesante fue ver el tema de *Voltage Feed Forward*, que basicamente es levantar componentes de tierra. Su forma más interesante, personalmente, es como hacerlo de forma activa donde se realimentan a los puntos de tierra virtual pudiendo formar bicuadráticas completas con estructuras activas conocidas como el ACK-MOS o el GIC.

# %%
from IPython.display import IFrame
IFrame("./docs/apuntes_clase7.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./docs/apuntes_Clase7.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Bibliografía utilizada
#
# Para esta clase se utilizó ampliamente el capítulo 5.2 del Schaumann. En específico las siguientes páginas:
#
# Capítulo 3, página 77 - Tabla 3.1 de funciones bilineales
#
# <img src="./pics/biblio1.png" align="center" width="1000" />
#
# Capítulo 5.2, página 210 - Componentes levantados de tierra
#
# <img src="./pics/biblio2.png" align="center" width="1000" />
#
# Capítulo 5.2, página 212 - Ack-Mos Bicuadrático completo
#
# <img src="./pics/biblio3.png" align="center" width="1000" />
#
# Capítulo 5.2, página 216 - GIC bicuadrático completo
#
# <img src="./pics/biblio4.png" align="center" width="1000" />

# %% [markdown]
# ## Diseño TPLAB1
#
# Para el TPLAB1 se pide diseñar un filtro para luego hacer mediciones en el laboratorio. Esta semana se empezó con el diseño del filtro A asignado a mi grupo.
#
# <img src="./pics/consigna.png" align="center" width="800" />
#
# Para diseñar el filtro se calculó el orden y el epsilon a mano y luego con estos datos se desarrolló la transferencia en python:
#
# ### Calculo a mano
#
# <img src="./pics/CalculoTPLAB1.jpg" align="center" width="800" />
#
# ### Simulacion numerica en python
#
# ![image.png](attachment:image.png)
#
# Una vez que se calculó la transferencia, se debe asignar el valor a los componentes utilizando la hoja de datos del integrado UAF42 que es el que se utilizará en el TPLAB1
#
# <img src="./pics/UAF42.png" align="center" width="800" />
#
# **Queda para la próxima semana asignar el valor a los componentes y armar el circuito físico para probarlo en el laboratorio abierto.**
#
# Para más detalles, proximamente... ***El informe del TPLAB1***

# %% [markdown]
# ## Tarea Semanal 4bis2
#
# Se adjunta el [link del jupyter de la TS4bis2](https://github.com/dlugano32/TC2_2023_Lugano/blob/main/Tareas_Semanales/TS4_bis2/TS4_bis2.ipynb) que al dia de la fecha (5/6) todavía está en proceso. En dicho link se detallará mejor que bibliografía se utilizó, además de la resolución de la consigna.
#
# Esta semana se hizo todo el diseño del pasabanda y su simulación. Queda pendiente para la proxima semana verificar el diseño con mi compañero de grupo y terminar el jupyter en colaboración.
#
# Es importante aclarar que esta tarea semanal fue por lejos la que mas me costó y por lo tanto la que más tiempo me llevó. Esto se debe a que nunca habia hecho el diseño de un pasabandas asimetrico, lo cual generó bastantes dudas a la hora de empezar el diseño. Luego también me costó bastante la implementación del filtro diseñado con el GIC pasabandas ya que la simulación no daba correctamente. Finalmente se pudo lograr cumplir con la plantilla, aunque el diseño quizá se pueda mejorar.
