# %% [markdown]
# <img src="../logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Evidencias clase 25 | 9/11
# #### Lugano Damian
#
# ----

# %% [markdown]
# ### Desarrollo de la tarea semanal 12
#
# Terminé la tarea semanal 12 de sintesis de cuadripolos simplemente cargados que habiamos empezado la clase 9/11.
#
# El link al [NbViewer](https://nbviewer.org/github/dlugano32/TC2_2023_Lugano/blob/main/Tareas_Semanales/TS12/TS12.ipynb)
#
# En total el desarollo de la tarea semanal me llevó unas **4Hs**
#
#
# ### Videos de la clase de parámetros S
#
# ![image.png](attachment:image.png)
#
# #### APuntes tomados en la clase

# %%
from IPython.display import IFrame
IFrame("./docs/Clase_ParametrosS.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./docs/Clase_ParametrosS.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# En total me llevó **3h40** ver los videos.
#
# El total de esta semana fueron **7h40**
