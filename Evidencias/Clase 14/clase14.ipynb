# %% [markdown]
# <img src="../logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Evidencias clase 14 - 17/8
# #### Lugano Damian
#
# -----------------

# %% [markdown]
# Tareas de esta semana:
#
# + TS6
# + Videos de filtros digitales

# %% [markdown]
# ### TS6
#
# La tarea semanal 6 fue la que mas me costó hasta el momento. En específico, no pude resolver el ejercicio 1 por lo que no la pude terminar esta semana.
#
# No fue una cuestión de dedicarle poco tiempo sino que no salió.
#
# Se hizo un jupyter de la TS6 que se puede acceder [aqui]()
#
# ##### En total se le dedicaron **9hs** a la tarea semanal

# %% [markdown]
# ### Clase filtros digitales
#
# Miré todos los videos de la clase de filtros digitales. LLevaron bastante tiempo ya que tenía mucho contenido que si bien se ve practicamente todo en asys tuve que repasar bastante el tema.
#
# ![fotoclase14.jpg](attachment:fotoclase14.jpg)
#
# #### Apuntes tomados en clase:

# %%
from IPython.display import IFrame
IFrame("./docs/Clase_14.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./docs/Clase_14.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Esta vez no fue necesario la bibliografía ya que usé mi carpeta de ASYS para repasar algunas cosas.
#
# En total se le dedicaron **7HS** para ver y entender todos los videos
#
# ##### Total de horas dedicadas esta semana: **16HS**
